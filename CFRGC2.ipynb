# %% [markdown]
# <a href="https://colab.research.google.com/github/srbharathee/DL/blob/master/CFRGC2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualize where the Convolutional Network is looking at using Grad-CAM for CIFAR10 dataset
#
# When solving image classification problems , it would be helpful for us to know what information from the image is being used by the network to make its preditions. Grad-CAM is a way for us to visualize the pixels in the activation channels that contribute most actively to a certain prediction . This will help us to fine tune the model in such a way that it uses all/most of the information belonging to the object being classified while making a prediction as opposed to using only small parts of the object or on the fringes or background surrounding the object being classified. This will help the model learn more about the features of a particular class .
#
# In this exercise we will do a Grad-CAM visualization on 50 misclassified images of CIFAR10 dataset. We will use a ResNet18 pretrained model from [https://github.com/qubvel/classification_models](https://github.com/qubvel/classification_models)

# %% [markdown]
# ### install the required files from qubvel keras applications project in order to get the pretrained ResNet model

# %%
# !pip install git+https://github.com/qubvel/classification_models.git
# Out:
# Collecting git+https://github.com/qubvel/classification_models.git
#   Cloning https://github.com/qubvel/classification_models.git to /tmp/pip-req-build-477q0yvi
#   Running command git clone -q https://github.com/qubvel/classification_models.git /tmp/pip-req-build-477q0yvi
#   Running command git submodule update --init --recursive -q
# Requirement already satisfied (use --upgrade to upgrade): image-classifiers==0.2.2 from git+https://github.com/qubvel/classification_models.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from image-classifiers==0.2.2) (2.2.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (1.3.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (1.16.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (2.8.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (1.1.0)
# Building wheels for collected packages: image-classifiers
#   Building wheel for image-classifiers (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r17hfe2p/wheels/de/2b/fd/29a6d33edb8c28bc7d94e95ea1d39c9a218ac500a3cfb1b197
# Successfully built image-classifiers

# %% [markdown]
# ### import necessary keras modules , numpy and matplotlib

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
#from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Activation, Flatten, Dropout
from keras.layers import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### import ResNet18 and image preprocessing from the project we installed earlier

# %%
import keras
from classification_models.resnet import ResNet18, preprocess_input

# %% [markdown]
# ### get cifar10 dataset from keras datasets

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %% [markdown]
# ### plot a selection of 10 images from the train dataset

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# ### Normalize pixel values in the images to be between 0 and 1
# ### convert the train and test labels to categorical data of 10 class categories

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ### preprocess the image data

# %%
train_features = preprocess_input(train_features)

test_features = preprocess_input(test_features)

# %% [markdown]
# ### we will now get the ResNet18 model weights for imagenet (Cifar is not available in this library).
# ### Change the input shape to match that of CIFAR10 : 32,32,3
# ### Add a 1x1 conv layer to squash the 512 channels of the pretrained model to 10 channels corresponding to 10 classes in CIFAR10
# ### Add GlobalAveragePooling to convert these to 1D inputs suitable for the softmax prediction layer
# ### Add softmax prediction

# %%
# build model
base_model = ResNet18(input_shape=(32,32,3), weights='imagenet', include_top=False)
x= Conv2D(num_classes,1,name='reducer1')(base_model.output) #reduce 512 activation channels to 10 = number of classes in cifar-10
#x= BatchNormalization()(x) - No BatchNorm
#x= Activation('relu')(x)   - No ReLU
x = keras.layers.GlobalAveragePooling2D()(x)  # add GlobalAveragePooling2D
output = keras.layers.Activation('softmax')(x) #add Softmax activation 
model = keras.models.Model(inputs=[base_model.input], outputs=[output])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0716 17:11:46.965218 140294074267520 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0716 17:11:46.999380 140294074267520 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0716 17:11:47.001122 140294074267520 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0716 17:11:47.003247 140294074267520 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0716 17:11:47.005136 140294074267520 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0716 17:11:47.546430 140294074267520 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0716 17:11:47.816578 140294074267520 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# ### print model summary and use this information to choose the layer that we will vuse for Grad-CAM visualization.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 32, 32, 3)    9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 38, 38, 3)    0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 16, 16, 64)   9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 16, 16, 64)   256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 16, 16, 64)   0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 18, 18, 64)   0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 8, 8, 64)     0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 8, 8, 64)     256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 8, 8, 64)     0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 10, 10, 64)   0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 8, 8, 64)     36864       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 8, 8, 64)     256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 8, 8, 64)     0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 10, 10, 64)   0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 8, 8, 64)     36864       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 8, 8, 64)     4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 8, 64)     0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 8, 8, 64)     256         add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 8, 8, 64)     0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 10, 10, 64)   0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 8, 8, 64)     36864       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 8, 8, 64)     256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 8, 8, 64)     0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 10, 10, 64)   0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 8, 8, 64)     36864       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 64)     0           stage1_unit2_conv2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 8, 8, 64)     256         add_2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 8, 8, 64)     0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 10, 10, 64)   0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 4, 4, 128)    73728       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 4, 4, 128)    512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 4, 4, 128)    0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 6, 6, 128)    0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 4, 4, 128)    147456      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 4, 4, 128)    8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, 4, 128)    0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 4, 4, 128)    512         add_3[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 4, 4, 128)    0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 6, 6, 128)    0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 4, 4, 128)    147456      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 4, 4, 128)    512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 4, 4, 128)    0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 6, 6, 128)    0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 4, 4, 128)    147456      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 4, 128)    0           stage2_unit2_conv2[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 4, 4, 128)    512         add_4[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 4, 4, 128)    0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 6, 6, 128)    0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 2, 2, 256)    294912      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 2, 2, 256)    1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 2, 2, 256)    0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 4, 4, 256)    0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 2, 2, 256)    589824      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 2, 2, 256)    32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 2, 2, 256)    0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 2, 2, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 2, 2, 256)    0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 4, 4, 256)    0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 2, 2, 256)    589824      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 2, 2, 256)    1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 2, 2, 256)    0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 4, 4, 256)    0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 2, 2, 256)    589824      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 2, 2, 256)    0           stage3_unit2_conv2[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 2, 2, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 2, 2, 256)    0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 4, 4, 256)    0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 1, 1, 512)    1179648     zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 1, 1, 512)    2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 1, 1, 512)    0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 3, 3, 512)    0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 1, 1, 512)    2359296     zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 1, 1, 512)    131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 1, 1, 512)    0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 1, 1, 512)    2048        add_7[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 1, 1, 512)    0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 3, 3, 512)    0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 1, 1, 512)    2359296     zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 1, 1, 512)    2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 1, 1, 512)    0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 3, 3, 512)    0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 1, 1, 512)    2359296     zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1, 1, 512)    0           stage4_unit2_conv2[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 1, 1, 512)    2048        add_8[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 1, 1, 512)    0           bn1[0][0]
# __________________________________________________________________________________________________
# reducer1 (Conv2D)               (None, 1, 1, 10)     5130        relu1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 10)           0           reducer1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10)           0           global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 11,192,019
# Trainable params: 11,184,077
# Non-trainable params: 7,942
# __________________________________________________________________________________________________

# %% [markdown]
# ### Plot the model as png image so that we can visualize the network better

# %%
#plot the model as a png image and display it 

from keras.utils import plot_model
plot_model(model, to_file='model.png')

from IPython.display import Image, display
display(Image('model.png'))

# %% [markdown]
# ### Layer named stage2_unit1_relu1 seems to be good candidate for the visualization.It has an output size of 8x8 . Layers after this are smaller (4x4 , 3x3 or 2x2)
#
# ### Compile the model using Stochastic Gradient descent optimizer with momentum of 0.9

# %%
# train
from keras.optimizers import SGD
opt=SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=False)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# W0716 17:11:51.562057 140294074267520 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ### we want to get the model with best validation accuracy for the prediction task and so we will save the best model from the various epochs in Google Drive using ModelCheckpoint callback available in Keras
# ### Mount Google Drive

# %%
from google.colab import drive 
drive.mount('/gdrive',force_remount=True)
# Out:
# Mounted at /gdrive

# %% [markdown]
# ### define a Modelcheckpoint to save the best Model

# %%
from keras.callbacks import ModelCheckpoint

model_save_path='/gdrive/My Drive/EIP3/session5/best_model2.h5'

chkpoint_model=ModelCheckpoint(model_save_path, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# %% [markdown]
# ##Cutout Augmentation
# Cutout was first presented as an effective augmentation technique in these two papers :
#
# [Improved Regularization of Convolutional Neural Networks with Cutout](https://arxiv.org/abs/1708.04552) and [Random Erasing Data Augmentation](https://arxiv.org/abs/1708.04896)
#
# The idea is to randomly cut away patches of information from images that a model is training on to force it to learn from more parts of the image. This would help the model learn more features about a class instead of depending on some simple assumptions using smaller areas within the image . This helps the model generalize better and make better predictions .
#
# We will use python code for random erasing found at [https://github.com/yu4u/cutout-random-erasing](https://github.com/yu4u/cutout-random-erasing)

# %%
#get code for random erasing from https://github.com/yu4u/cutout-random-erasing
# !wget https://raw.githubusercontent.com/yu4u/cutout-random-erasing/master/random_eraser.py
# Out:
# --2019-07-16 17:11:56--  https://raw.githubusercontent.com/yu4u/cutout-random-erasing/master/random_eraser.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 888 [text/plain]
# Saving to: ‘random_eraser.py.3’
#
# random_eraser.py.3  100%[===================>]     888  --.-KB/s    in 0s
#
# 2019-07-16 17:11:56 (125 MB/s) - ‘random_eraser.py.3’ saved [888/888]

# %% [markdown]
# ### Train the model for 100 epochs using a batch size of 128  . We will use a ImageDataGenerator to apply image augmentation of horizontal Flip and CutOut augmentation for the training

# %%
from keras.preprocessing.image import ImageDataGenerator
from random_eraser import get_random_eraser

batch_size=128

train_datagen=ImageDataGenerator(
        #featurewise_center=True,  # set input mean to 0 over the dataset
        #samplewise_center=False,  # set each sample mean to 0
        #featurewise_std_normalization=True,  # divide inputs by std of the dataset
        #samplewise_std_normalization=False,  # divide each input by its std
        preprocessing_function=get_random_eraser(v_l=0, v_h=1),
        horizontal_flip=True
    
)

val_datagen= ImageDataGenerator(
        #featurewise_center=True,  # set input mean to 0 over the dataset
        
        #featurewise_std_normalization=True,  # divide inputs by std of the dataset
        
)


train_datagen.fit(train_features)

val_datagen.fit(test_features)

training_generator=train_datagen.flow(train_features,train_labels, batch_size=batch_size,shuffle=True,seed=42)

validation_generator=val_datagen.flow(test_features,test_labels, batch_size=batch_size,shuffle=True,seed=42)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(training_generator, epochs=100, 
                        steps_per_epoch=np.ceil(train_features.shape[0]/batch_size), 
                    validation_steps=np.ceil(test_features.shape[0]/batch_size), 
                    validation_data=validation_generator,
                                 shuffle=True,
                                 callbacks=[chkpoint_model],
                                 verbose=1)
# Out:
# W0716 17:11:59.209130 140294074267520 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 391/391 [==============================] - 45s 114ms/step - loss: 1.0335 - acc: 0.6448 - val_loss: 0.6806 - val_acc: 0.7663
#
# Epoch 00001: val_acc improved from -inf to 0.76630, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 2/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.7065 - acc: 0.7537 - val_loss: 0.6369 - val_acc: 0.7825
#
# Epoch 00002: val_acc improved from 0.76630 to 0.78250, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 3/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6212 - acc: 0.7824 - val_loss: 0.5727 - val_acc: 0.8021
#
# Epoch 00003: val_acc improved from 0.78250 to 0.80210, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 4/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5572 - acc: 0.8055 - val_loss: 0.5887 - val_acc: 0.7992
#
# Epoch 00004: val_acc did not improve from 0.80210
# Epoch 5/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5104 - acc: 0.8222 - val_loss: 0.5725 - val_acc: 0.8060
#
# Epoch 00005: val_acc improved from 0.80210 to 0.80600, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 6/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.4703 - acc: 0.8364 - val_loss: 0.5379 - val_acc: 0.8165
#
# Epoch 00006: val_acc improved from 0.80600 to 0.81650, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 7/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.4353 - acc: 0.8475 - val_loss: 0.5236 - val_acc: 0.8235
#
# Epoch 00007: val_acc improved from 0.81650 to 0.82350, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 8/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.4097 - acc: 0.8563 - val_loss: 0.5700 - val_acc: 0.8154
#
# Epoch 00008: val_acc did not improve from 0.82350
# Epoch 9/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.3793 - acc: 0.8680 - val_loss: 0.5707 - val_acc: 0.8174
#
# Epoch 00009: val_acc did not improve from 0.82350
# Epoch 10/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.3632 - acc: 0.8723 - val_loss: 0.5503 - val_acc: 0.8194
#
# Epoch 00010: val_acc did not improve from 0.82350
# Epoch 11/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.3393 - acc: 0.8829 - val_loss: 0.6685 - val_acc: 0.8079
#
# Epoch 00011: val_acc did not improve from 0.82350
# Epoch 12/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.3171 - acc: 0.8893 - val_loss: 0.5475 - val_acc: 0.8309
#
# Epoch 00012: val_acc improved from 0.82350 to 0.83090, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 13/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.3092 - acc: 0.8922 - val_loss: 0.5103 - val_acc: 0.8441
#
# Epoch 00013: val_acc improved from 0.83090 to 0.84410, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 14/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2872 - acc: 0.9000 - val_loss: 0.5877 - val_acc: 0.8232
#
# Epoch 00014: val_acc did not improve from 0.84410
# Epoch 15/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2787 - acc: 0.9030 - val_loss: 0.5529 - val_acc: 0.8390
#
# Epoch 00015: val_acc did not improve from 0.84410
# Epoch 16/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2688 - acc: 0.9061 - val_loss: 0.5481 - val_acc: 0.8348
#
# Epoch 00016: val_acc did not improve from 0.84410
# Epoch 17/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2528 - acc: 0.9118 - val_loss: 0.5028 - val_acc: 0.8417
#
# Epoch 00017: val_acc did not improve from 0.84410
# Epoch 18/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2403 - acc: 0.9169 - val_loss: 0.5710 - val_acc: 0.8305
#
# Epoch 00018: val_acc did not improve from 0.84410
# Epoch 19/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2407 - acc: 0.9168 - val_loss: 0.5496 - val_acc: 0.8406
#
# Epoch 00019: val_acc did not improve from 0.84410
# Epoch 20/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2242 - acc: 0.9221 - val_loss: 0.6023 - val_acc: 0.8273
#
# Epoch 00020: val_acc did not improve from 0.84410
# Epoch 21/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.2205 - acc: 0.9233 - val_loss: 0.5938 - val_acc: 0.8408
#
# Epoch 00021: val_acc did not improve from 0.84410
# Epoch 22/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2119 - acc: 0.9254 - val_loss: 0.6292 - val_acc: 0.8344
#
# Epoch 00022: val_acc did not improve from 0.84410
# Epoch 23/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.2041 - acc: 0.9279 - val_loss: 0.5677 - val_acc: 0.8441
#
# Epoch 00023: val_acc did not improve from 0.84410
# Epoch 24/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1953 - acc: 0.9327 - val_loss: 0.6159 - val_acc: 0.8391
#
# Epoch 00024: val_acc did not improve from 0.84410
# Epoch 25/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1919 - acc: 0.9325 - val_loss: 0.5782 - val_acc: 0.8453
#
# Epoch 00025: val_acc improved from 0.84410 to 0.84530, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 26/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1827 - acc: 0.9369 - val_loss: 0.6168 - val_acc: 0.8374
#
# Epoch 00026: val_acc did not improve from 0.84530
# Epoch 27/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1809 - acc: 0.9367 - val_loss: 0.6301 - val_acc: 0.8429
#
# Epoch 00027: val_acc did not improve from 0.84530
# Epoch 28/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1729 - acc: 0.9401 - val_loss: 0.5652 - val_acc: 0.8509
#
# Epoch 00028: val_acc improved from 0.84530 to 0.85090, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 29/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1687 - acc: 0.9426 - val_loss: 0.5709 - val_acc: 0.8526
#
# Epoch 00029: val_acc improved from 0.85090 to 0.85260, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 30/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1661 - acc: 0.9428 - val_loss: 0.6132 - val_acc: 0.8456
#
# Epoch 00030: val_acc did not improve from 0.85260
# Epoch 31/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1597 - acc: 0.9449 - val_loss: 0.6049 - val_acc: 0.8522
#
# Epoch 00031: val_acc did not improve from 0.85260
# Epoch 32/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1565 - acc: 0.9451 - val_loss: 0.5902 - val_acc: 0.8496
#
# Epoch 00032: val_acc did not improve from 0.85260
# Epoch 33/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1536 - acc: 0.9457 - val_loss: 0.6330 - val_acc: 0.8463
#
# Epoch 00033: val_acc did not improve from 0.85260
# Epoch 34/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1508 - acc: 0.9481 - val_loss: 0.6139 - val_acc: 0.8530
#
# Epoch 00034: val_acc improved from 0.85260 to 0.85300, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 35/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1483 - acc: 0.9491 - val_loss: 0.6095 - val_acc: 0.8520
#
# Epoch 00035: val_acc did not improve from 0.85300
# Epoch 36/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1495 - acc: 0.9491 - val_loss: 0.6231 - val_acc: 0.8503
#
# Epoch 00036: val_acc did not improve from 0.85300
# Epoch 37/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1437 - acc: 0.9512 - val_loss: 0.6108 - val_acc: 0.8480
#
# Epoch 00037: val_acc did not improve from 0.85300
# Epoch 38/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.1380 - acc: 0.9521 - val_loss: 0.6608 - val_acc: 0.8469
#
# Epoch 00038: val_acc did not improve from 0.85300
# Epoch 39/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1353 - acc: 0.9534 - val_loss: 0.6505 - val_acc: 0.8477
#
# Epoch 00039: val_acc did not improve from 0.85300
# Epoch 40/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1328 - acc: 0.9547 - val_loss: 0.6550 - val_acc: 0.8418
#
# Epoch 00040: val_acc did not improve from 0.85300
# Epoch 41/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1305 - acc: 0.9555 - val_loss: 0.6319 - val_acc: 0.8512
#
# Epoch 00041: val_acc did not improve from 0.85300
# Epoch 42/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1291 - acc: 0.9557 - val_loss: 0.6117 - val_acc: 0.8530
#
# Epoch 00042: val_acc did not improve from 0.85300
# Epoch 43/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1241 - acc: 0.9583 - val_loss: 0.6614 - val_acc: 0.8527
#
# Epoch 00043: val_acc did not improve from 0.85300
# Epoch 44/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1281 - acc: 0.9570 - val_loss: 0.6305 - val_acc: 0.8545
#
# Epoch 00044: val_acc improved from 0.85300 to 0.85450, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 45/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.1231 - acc: 0.9582 - val_loss: 0.6405 - val_acc: 0.8515
#
# Epoch 00045: val_acc did not improve from 0.85450
# Epoch 46/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1205 - acc: 0.9597 - val_loss: 0.6212 - val_acc: 0.8484
#
# Epoch 00046: val_acc did not improve from 0.85450
# Epoch 47/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1120 - acc: 0.9615 - val_loss: 0.6132 - val_acc: 0.8541
#
# Epoch 00047: val_acc did not improve from 0.85450
# Epoch 48/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1160 - acc: 0.9602 - val_loss: 0.6425 - val_acc: 0.8530
#
# Epoch 00048: val_acc did not improve from 0.85450
# Epoch 49/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1197 - acc: 0.9591 - val_loss: 0.6649 - val_acc: 0.8461
#
# Epoch 00049: val_acc did not improve from 0.85450
# Epoch 50/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1109 - acc: 0.9615 - val_loss: 0.6603 - val_acc: 0.8511
#
# Epoch 00050: val_acc did not improve from 0.85450
# Epoch 51/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1099 - acc: 0.9621 - val_loss: 0.5920 - val_acc: 0.8545
#
# Epoch 00051: val_acc did not improve from 0.85450
# Epoch 52/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1084 - acc: 0.9640 - val_loss: 0.6387 - val_acc: 0.8525
#
# Epoch 00052: val_acc did not improve from 0.85450
# Epoch 53/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1100 - acc: 0.9619 - val_loss: 0.6990 - val_acc: 0.8442
#
# Epoch 00053: val_acc did not improve from 0.85450
# Epoch 54/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1062 - acc: 0.9643 - val_loss: 0.6731 - val_acc: 0.8500
#
# Epoch 00054: val_acc did not improve from 0.85450
# Epoch 55/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1024 - acc: 0.9640 - val_loss: 0.6681 - val_acc: 0.8530
#
# Epoch 00055: val_acc did not improve from 0.85450
# Epoch 56/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1055 - acc: 0.9639 - val_loss: 0.6474 - val_acc: 0.8525
#
# Epoch 00056: val_acc did not improve from 0.85450
# Epoch 57/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1010 - acc: 0.9659 - val_loss: 0.6763 - val_acc: 0.8556
#
# Epoch 00057: val_acc improved from 0.85450 to 0.85560, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 58/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.1005 - acc: 0.9662 - val_loss: 0.7125 - val_acc: 0.8485
#
# Epoch 00058: val_acc did not improve from 0.85560
# Epoch 59/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.1018 - acc: 0.9652 - val_loss: 0.6486 - val_acc: 0.8526
#
# Epoch 00059: val_acc did not improve from 0.85560
# Epoch 60/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0989 - acc: 0.9666 - val_loss: 0.6863 - val_acc: 0.8518
#
# Epoch 00060: val_acc did not improve from 0.85560
# Epoch 61/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0967 - acc: 0.9663 - val_loss: 0.6586 - val_acc: 0.8540
#
# Epoch 00061: val_acc did not improve from 0.85560
# Epoch 62/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0970 - acc: 0.9666 - val_loss: 0.6598 - val_acc: 0.8544
#
# Epoch 00062: val_acc did not improve from 0.85560
# Epoch 63/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0980 - acc: 0.9670 - val_loss: 0.6252 - val_acc: 0.8556
#
# Epoch 00063: val_acc did not improve from 0.85560
# Epoch 64/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0944 - acc: 0.9684 - val_loss: 0.6315 - val_acc: 0.8552
#
# Epoch 00064: val_acc did not improve from 0.85560
# Epoch 65/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0928 - acc: 0.9689 - val_loss: 0.6549 - val_acc: 0.8551
#
# Epoch 00065: val_acc did not improve from 0.85560
# Epoch 66/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0954 - acc: 0.9670 - val_loss: 0.6259 - val_acc: 0.8596
#
# Epoch 00066: val_acc improved from 0.85560 to 0.85960, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 67/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0900 - acc: 0.9691 - val_loss: 0.6393 - val_acc: 0.8552
#
# Epoch 00067: val_acc did not improve from 0.85960
# Epoch 68/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0848 - acc: 0.9711 - val_loss: 0.6793 - val_acc: 0.8505
#
# Epoch 00068: val_acc did not improve from 0.85960
# Epoch 69/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0860 - acc: 0.9705 - val_loss: 0.6639 - val_acc: 0.8578
#
# Epoch 00069: val_acc did not improve from 0.85960
# Epoch 70/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0875 - acc: 0.9695 - val_loss: 0.6488 - val_acc: 0.8583
#
# Epoch 00070: val_acc did not improve from 0.85960
# Epoch 71/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0916 - acc: 0.9687 - val_loss: 0.6292 - val_acc: 0.8545
#
# Epoch 00071: val_acc did not improve from 0.85960
# Epoch 72/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0874 - acc: 0.9699 - val_loss: 0.6929 - val_acc: 0.8535
#
# Epoch 00072: val_acc did not improve from 0.85960
# Epoch 73/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0825 - acc: 0.9729 - val_loss: 0.7423 - val_acc: 0.8480
#
# Epoch 00073: val_acc did not improve from 0.85960
# Epoch 74/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0832 - acc: 0.9711 - val_loss: 0.7037 - val_acc: 0.8529
#
# Epoch 00074: val_acc did not improve from 0.85960
# Epoch 75/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0804 - acc: 0.9717 - val_loss: 0.6975 - val_acc: 0.8529
#
# Epoch 00075: val_acc did not improve from 0.85960
# Epoch 76/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0816 - acc: 0.9730 - val_loss: 0.6607 - val_acc: 0.8570
#
# Epoch 00076: val_acc did not improve from 0.85960
# Epoch 77/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0823 - acc: 0.9724 - val_loss: 0.6612 - val_acc: 0.8581
#
# Epoch 00077: val_acc did not improve from 0.85960
# Epoch 78/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0802 - acc: 0.9728 - val_loss: 0.6519 - val_acc: 0.8576
#
# Epoch 00078: val_acc did not improve from 0.85960
# Epoch 79/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0787 - acc: 0.9734 - val_loss: 0.6407 - val_acc: 0.8578
#
# Epoch 00079: val_acc did not improve from 0.85960
# Epoch 80/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0785 - acc: 0.9737 - val_loss: 0.6994 - val_acc: 0.8547
#
# Epoch 00080: val_acc did not improve from 0.85960
# Epoch 81/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0787 - acc: 0.9736 - val_loss: 0.6668 - val_acc: 0.8589
#
# Epoch 00081: val_acc did not improve from 0.85960
# Epoch 82/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0811 - acc: 0.9723 - val_loss: 0.7519 - val_acc: 0.8424
#
# Epoch 00082: val_acc did not improve from 0.85960
# Epoch 83/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0766 - acc: 0.9737 - val_loss: 0.6733 - val_acc: 0.8553
#
# Epoch 00083: val_acc did not improve from 0.85960
# Epoch 84/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.0746 - acc: 0.9742 - val_loss: 0.7219 - val_acc: 0.8508
#
# Epoch 00084: val_acc did not improve from 0.85960
# Epoch 85/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0779 - acc: 0.9735 - val_loss: 0.7272 - val_acc: 0.8535
#
# Epoch 00085: val_acc did not improve from 0.85960
# Epoch 86/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0724 - acc: 0.9754 - val_loss: 0.6849 - val_acc: 0.8572
#
# Epoch 00086: val_acc did not improve from 0.85960
# Epoch 87/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0742 - acc: 0.9747 - val_loss: 0.6608 - val_acc: 0.8604
#
# Epoch 00087: val_acc improved from 0.85960 to 0.86040, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 88/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0748 - acc: 0.9741 - val_loss: 0.6852 - val_acc: 0.8604
#
# Epoch 00088: val_acc did not improve from 0.86040
# Epoch 89/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.0752 - acc: 0.9735 - val_loss: 0.6676 - val_acc: 0.8574
#
# Epoch 00089: val_acc did not improve from 0.86040
# Epoch 90/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0719 - acc: 0.9750 - val_loss: 0.6539 - val_acc: 0.8621
#
# Epoch 00090: val_acc improved from 0.86040 to 0.86210, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 91/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.0714 - acc: 0.9758 - val_loss: 0.6709 - val_acc: 0.8586
#
# Epoch 00091: val_acc did not improve from 0.86210
# Epoch 92/100
# 391/391 [==============================] - 40s 101ms/step - loss: 0.0748 - acc: 0.9744 - val_loss: 0.6820 - val_acc: 0.8580
#
# Epoch 00092: val_acc did not improve from 0.86210
# Epoch 93/100
# 391/391 [==============================] - 41s 106ms/step - loss: 0.0709 - acc: 0.9762 - val_loss: 0.6967 - val_acc: 0.8604
#
# Epoch 00093: val_acc did not improve from 0.86210
# Epoch 94/100
# 391/391 [==============================] - 40s 102ms/step - loss: 0.0697 - acc: 0.9763 - val_loss: 0.6852 - val_acc: 0.8571
#
# Epoch 00094: val_acc did not improve from 0.86210
# Epoch 95/100
# 391/391 [==============================] - 40s 103ms/step - loss: 0.0709 - acc: 0.9755 - val_loss: 0.6763 - val_acc: 0.8634
#
# Epoch 00095: val_acc improved from 0.86210 to 0.86340, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 96/100
# 391/391 [==============================] - 40s 103ms/step - loss: 0.0697 - acc: 0.9763 - val_loss: 0.6938 - val_acc: 0.8563
#
# Epoch 00096: val_acc did not improve from 0.86340
# Epoch 97/100
# 391/391 [==============================] - 40s 103ms/step - loss: 0.0673 - acc: 0.9765 - val_loss: 0.6733 - val_acc: 0.8609
#
# Epoch 00097: val_acc did not improve from 0.86340
# Epoch 98/100
# 391/391 [==============================] - 40s 103ms/step - loss: 0.0683 - acc: 0.9758 - val_loss: 0.6942 - val_acc: 0.8534
#
# Epoch 00098: val_acc did not improve from 0.86340
# Epoch 99/100
# 391/391 [==============================] - 40s 103ms/step - loss: 0.0663 - acc: 0.9769 - val_loss: 0.6865 - val_acc: 0.8635
#
# Epoch 00099: val_acc improved from 0.86340 to 0.86350, saving model to /gdrive/My Drive/EIP3/session5/best_model2.h5
# Epoch 100/100
# 391/391 [==============================] - 40s 103ms/step - loss: 0.0670 - acc: 0.9765 - val_loss: 0.6707 - val_acc: 0.8604
#
# Epoch 00100: val_acc did not improve from 0.86350

# %% [markdown]
# ### The network was trained for 100 epochs and reached a max validation accuracy of 86.35 . We have saved the model with best validation accuracy in google drive so that we can load and use it for prediction and Grad-CAM visualization
#
# ### Now let us define the function for Grad-CAM visualization .
# ### This function named gradcam takes as input the model , the set of images , the labels for each image and the layer to be used for calculating gradients .
# ### It returns a list of dictionaries containing original image , the heatmap, the titles to display during visualization

# %%
import cv2
from mpl_toolkits.axes_grid1 import ImageGrid
from google.colab.patches import cv2_imshow
from IPython.core.display import display, HTML


#select test images and corresponding labels to print heatmap 
#x=np.array([test_features[41],test_features[410],test_features[222],test_features[950]])
#y=[test_labels[41],test_labels[410],test_labels[222],test_labels[950]]


def gradcam(model1,x,y,which_layer):
  #
  results=[]
  #make prediction for these 4 images 
  preds = model1.predict(x)
  for j in range(x.shape[0]):
    #get class id from the prediction values 
    class_idx = np.argmax(preds[j])

    class_output = model1.output[:, class_idx]
  
    ## choose the layer nearest to prediction that has a size of about 7x7 or 8x8 
    #in this case it is the layer being sent to the gradcam function 
    last_conv_layer = model1.get_layer(which_layer)
  
    # compute gradients and from heatmap 
    grads = K.gradients(class_output, last_conv_layer.output)[0]
    pooled_grads = K.mean(grads, axis=(0, 1, 2))
    iterate = K.function([model1.input], [pooled_grads, last_conv_layer.output[0]])
    pooled_grads_value, conv_layer_output_value = iterate([x])
    
    #apply the pooled grad value to the conv layer channels 
    for i in range(64):
      
      conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
      
    #get the mean of the weighted values and assign to heatmap   
    heatmap = np.mean(conv_layer_output_value, axis=-1)
    #retain only positive values (or 0) in heatmap 
    heatmap = np.maximum(heatmap, 0)
    #convert values between 0 and 1 using divide by max value 
    heatmap /= np.max(heatmap) 
    #we now have a heatmap with size equal to the output size of the layer we chose 
    
    #img is the image we are running gradcam on 
    img = x[j]
    
    #resize heatmap 8x8 to image size of 32x32 
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    #convert pixel values to be between 0 and 255 
    heatmap = np.uint8(255 * heatmap)
    #apply suitable cv2 colormap . In this case colormap_JET 
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  
    # convert from BGR to RGB if we want to display using matplotlib 
    heatmap1 = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)
    
    # create superimposed image if we want to print using cv2 (cv2_imshow supported in colab)
    superimposed_img = cv2.addWeighted(img, 0.5, heatmap1, 0.5, 0,dtype=5)
    
    #create a dictionary object with details of image, heatmap, its title 
    title1=str(j+1)+": "+ class_names[np.argmax(y[j])]+"\npredicted as\n"+str(class_names[class_idx])
    title2='superimposed\nheatmap'
    image1=img
    image2=heatmap1
    image3=superimposed_img
    imageObj={'image1':image1,'image2':image2,'image3':image3,'title1':title1,'title2':title2}
    
    #append the image dict object to results list 
    results.append(imageObj)
    #print(j)
  #return grad-cam results as a list of dictionary objects , each containing an image and its heatmap  
  return results

# %% [markdown]
# ### Define the function to display the Grad-CAM visualizations .
# ### This function displays a set of two images with heatmap visuals per row

# %%
def displayRow(images):
  # we will plot 2 images in a row 
  # cv.imshow does not work in jupyter notebooks and colab 
  # cv2_imshow patch works on colab but matplotlib gives us a little more flexibility in formatting the display
  # we will use matplotlib to print the image and its heatmap 
  fig = plt.figure(1, (13,13))

  grid = ImageGrid(fig, 111,  
                 nrows_ncols=(1,5),  
                 axes_pad=1,label_mode="1"  
                 )
  
  #horizontal spacer
  
    
  #grid[0].imshow(np.ones((32, 10)),alpha=0)
  #grid[0].axis('off')
  
  
  
  #first image
  #print(" original class is :"+class_names[np.argmax(y[j])]+" and predicted class is :"+str(class_names[class_idx]))
  grid[0].imshow(images[0]['image1'])
  grid[0].set_title(images[0]['title1'])
  grid[0].axis('off')
  
  #print the original image and on top of it place the heat map at 60% transparency 
  grid[1].imshow(images[0]['image1'],alpha=0.9)
  grid[1].imshow(images[0]['image2'],alpha=0.6)
  grid[1].set_title(images[0]['title2'])
  grid[1].axis('off')
  
  #vertical separator 
    
  grid[2].imshow(np.ones((32, 1)))
  grid[2].axis('off')
  
  #second image 
    
  #print(" original class is :"+class_names[np.argmax(y[j])]+" and predicted class is :"+str(class_names[class_idx]))
  grid[3].imshow(images[1]['image1'])
  grid[3].set_title(images[1]['title1'])
  grid[3].axis('off')
  
  #print the original image and on top of it place the heat map at 60% transparency 
  grid[4].imshow(images[1]['image1'],alpha=0.9)
  grid[4].imshow(images[1]['image2'],alpha=0.6)
  grid[4].set_title(images[1]['title2'])
  grid[4].axis('off')
  
  
  
  plt.show()
  display(HTML("<hr size='5' color='black' width='100%' align='center' />"))

# %% [markdown]
# ### Now that we have done the preparatory work for the visualization , let us load the model with best validation accuracy from earlier training

# %%
from keras.models import load_model
model=load_model(model_save_path)

# %% [markdown]
# ### Make predictions using the model and collect all the images that were classified wrongly

# %%
pred=model.predict(test_features)
pred2=np.argmax(pred,axis=1)
wrong_set=[]
correct_set=[]
wrong_labels=[]
true_labels=[]
wrong_indices=[]
for i in range(test_features.shape[0]):
  
  if (pred2[i]==np.argmax(test_labels[i])):
    
    correct_set.append(test_features[i])
  else:
    wrong_indices.append(i)
    wrong_labels.append(class_names[pred2[i]])
    true_labels.append(class_names[np.argmax(test_labels[i])])
    wrong_set.append(test_features[i])

# %% [markdown]
# ### Now take the first 50 images and the corresponding labels to create the data for Grad-CAM visualization

# %%
#take the first 50 images and labels from misclassified set 
w_list=wrong_indices[:50]
x=[]
y=[]
for i in range(len(w_list)):
  x.append(test_features[w_list[i]])
  y.append(test_labels[w_list[i]])
  
#convert the image list to numpy array   
x=np.array(x)

# %% [markdown]
# ### Obtain results from the gradcam function

# %%
results=gradcam(model,x,y,'stage2_unit1_relu1') # we choose this layer as the layer nearest to prediction and having a size of 8x8

# %% [markdown]
# ### display the results from gradcam function with images and corresponding heatmap visuals

# %%
display(HTML("<h2 align='center'>First 50 misclassified images with Grad-CAM heatmap </h2><hr size='5' color='black' width='100%' align='center' />"))
for i in range(0,len(results),2):
  images=[]
  images.append(results[i])
  images.append(results[i+1])
  displayRow(images)
# Out:
# <h2 align='center'>First 50 misclassified images with Grad-CAM heatmap </h2><hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />

# %% [markdown]
# ### We used a pre-trained a ResNet18 model to learn the CIFAR10 dataset . We made predictions on the dataset and collected 50 misclassified images. We then used Grad-CAM to visualize the heatmap for each of these 50 images and displayed the images together with the heatmaps for a better undertsanding of where the model is looking at or which pixels in a chosen layer are most actively contributing when making predictions for a certain class
