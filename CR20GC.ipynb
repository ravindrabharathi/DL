# %% [markdown]
# <a href="https://colab.research.google.com/github/srbharathee/DL/blob/master/CR20GC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualize where the Convolutional Network is looking at using Grad-CAM for CIFAR10 dataset
#
# When solving image classification problems , it would be helpful for us to know what information from the image is being used by the network to make its preditions. Grad-CAM is a way for us to visualize the pixels in the activation channels that contribute most actively to a certain prediction . This will help us to fine tune the model in such a way that it uses all/most of the information belonging to the object being classified while making a prediction as opposed to using only small parts of the object or on the fringes or background surrounding the object being classified. This will help the model learn more about the features of a particular class .
#
# In this exercise we will do a Grad-CAM visualization on 50 misclassified images of CIFAR10 dataset. We will use a ResNet18 model based on the notes for CIFAR-10 in the [RESNET paper](https://arxiv.org/pdf/1512.03385.pdf)
#
# ![resnet-notes1](https://raw.githubusercontent.com/srbharathee/DL/master/images/resnet-notes1.png)
# ![resnet-notes2](https://raw.githubusercontent.com/srbharathee/DL/master/images/resnet-notes2.png)
#
# Based on these experiments of the authors on CIFAR-10 a Resnet20 Model has been defined in [https://github.com/keras-team/keras/blob/master/examples/cifar10_resnet.py](https://github.com/keras-team/keras/blob/master/examples/cifar10_resnet.py) . We will use ResNetv2 from this project  for CIFAR-10 dataset .
#
# We will make a few small changes:
# 1. Remove the last Dense layer
# 2. Add a Conv2D 1x1 to reduce the number of channels to 10 (reducer1)
#
# The modified file is at [https://raw.githubusercontent.com/srbharathee/DL/master/cifar10_resnet20.py](https://raw.githubusercontent.com/srbharathee/DL/master/cifar10_resnet20.py)
#
#
# We will add the following image augmentations
# 1. Cutout/Random Eraser augmentation as defined in [https://github.com/yu4u/cutout-random-erasing](https://github.com/yu4u/cutout-random-erasing)
# 2.  random horizontal flip ,
# 3. random width_shift of .1
# 4. random height_shift of 0.1
#
# Afetr training the model for 100 epochs , we will do a prediction on the test dataset and  get the first 50 misclassified images .
#
# We will apply Grad-CAM visualization on these 50 misclassified images

# %% [markdown]
# ### get the Modified ResNet file which is based on an implementation from keras-team project

# %%
# !wget https://raw.githubusercontent.com/srbharathee/DL/master/cifar10_resnet20.py
# Out:
# --2019-07-17 04:02:55--  https://raw.githubusercontent.com/srbharathee/DL/master/cifar10_resnet20.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11268 (11K) [text/plain]
# Saving to: ‘cifar10_resnet20.py’
#
# cifar10_resnet20.py 100%[===================>]  11.00K  --.-KB/s    in 0s
#
# 2019-07-17 04:02:56 (120 MB/s) - ‘cifar10_resnet20.py’ saved [11268/11268]

# %% [markdown]
# ### import necessary keras modules , numpy and matplotlib

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
#from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Activation, Flatten, Dropout
from keras.layers import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### import ResNet18 and image preprocessing from the project we installed earlier

# %%
import cifar10_resnet20

# %%
model=cifar10_resnet20.resnet_v2(input_shape=(32,32,3),depth=cifar10_resnet20.depth)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0717 04:02:59.490058 139781615036288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0717 04:02:59.539329 139781615036288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0717 04:02:59.548643 139781615036288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0717 04:02:59.605233 139781615036288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0717 04:02:59.606299 139781615036288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0717 04:03:02.553483 139781615036288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0717 04:03:04.804013 139781615036288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
cifar10_resnet20.depth
# Out:
# 20

# %% [markdown]
# ### print model summary and use this information to choose the layer that we will vuse for Grad-CAM visualization.
#
# ### We will use 'reducer1' with size of 8x8

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   272         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   1088        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   1088        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   1040        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   1088        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   4160        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  8320        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  8320        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   8256        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  8320        activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 128)  0           add_3[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 128)  512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 128)    16512       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 128)    512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    33024       add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    33024       activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           conv2d_19[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    32896       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 128)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 128)    147584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 128)    512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 128)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 256)    33024       activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 256)    0           add_5[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 256)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# reducer1 (Conv2D)               (None, 8, 8, 10)     2570        activation_19[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 10)     0           reducer1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 574,090
# Trainable params: 570,602
# Non-trainable params: 3,488
# __________________________________________________________________________________________________

# %% [markdown]
# ### Plot the model as png image so that we can visualize the network better

# %%
#plot the model as a png image and display it 

from keras.utils import plot_model
plot_model(model, to_file='model.png')

from IPython.display import Image, display
display(Image('model.png'))

# %% [markdown]
# ### We will choose the layer 'reducer1' (which is nearest to prediction and has a size of 8x8 ) to be used for Grad-CAM Visualization

# %% [markdown]
# ### get cifar10 dataset from keras datasets

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %% [markdown]
# ### plot a selection of 10 images from the train dataset

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# ### Normalize pixel values in the images to be between 0 and 1
# ### convert the train and test labels to categorical data of 10 class categories

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ### Compile the model using Stochastic Gradient descent optimizer with momentum of 0.9

# %%
# train
from keras.optimizers import SGD
opt=SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=False)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# W0717 04:03:14.977518 139781615036288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ### we want to get the model with best validation accuracy for the prediction task and so we will save the best model from the various epochs in Google Drive using ModelCheckpoint callback available in Keras
# ### Mount Google Drive

# %%
from google.colab import drive 
drive.mount('/gdrive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %% [markdown]
# ### define a Modelcheckpoint to save the best Model

# %%
from keras.callbacks import ModelCheckpoint

model_save_path='/gdrive/My Drive/EIP3/session5/best_model3.h5'

chkpoint_model=ModelCheckpoint(model_save_path, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# %% [markdown]
# ##Cutout Augmentation
# Cutout was first presented as an effective augmentation technique in these two papers :
#
# [Improved Regularization of Convolutional Neural Networks with Cutout](https://arxiv.org/abs/1708.04552) and [Random Erasing Data Augmentation](https://arxiv.org/abs/1708.04896)
#
# The idea is to randomly cut away patches of information from images that a model is training on to force it to learn from more parts of the image. This would help the model learn more features about a class instead of depending on some simple assumptions using smaller areas within the image . This helps the model generalize better and make better predictions .
#
# We will use python code for random erasing found at [https://github.com/yu4u/cutout-random-erasing](https://github.com/yu4u/cutout-random-erasing)

# %%
#get code for random erasing from https://github.com/yu4u/cutout-random-erasing
# !wget https://raw.githubusercontent.com/yu4u/cutout-random-erasing/master/random_eraser.py
# Out:
# --2019-07-17 04:03:43--  https://raw.githubusercontent.com/yu4u/cutout-random-erasing/master/random_eraser.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 888 [text/plain]
# Saving to: ‘random_eraser.py’
#
# random_eraser.py    100%[===================>]     888  --.-KB/s    in 0s
#
# 2019-07-17 04:03:44 (135 MB/s) - ‘random_eraser.py’ saved [888/888]

# %% [markdown]
# ### Train the model for 100 epochs using a batch size of 128  . We will use a ImageDataGenerator to apply image augmentation of random horizontal Flip, width_shift range of 0.1 and height shift of range 0.1  and CutOut augmentation for the training . We will also permorf image normalization on the train and test datsets using featurewise_center and featurewise_std_normalization set to True

# %%
from keras.preprocessing.image import ImageDataGenerator
from random_eraser import get_random_eraser

batch_size=128

train_datagen=ImageDataGenerator(
        featurewise_center=True,  # set input mean to 0 over the dataset
        #samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=True,  # divide inputs by std of the dataset
        #samplewise_std_normalization=False,  # divide each input by its std
        preprocessing_function=get_random_eraser(v_l=0, v_h=1),
        horizontal_flip=True, width_shift_range=0.1,height_shift_range=0.1
    
)

val_datagen= ImageDataGenerator(
        featurewise_center=True,  # set input mean to 0 over the dataset
        
        featurewise_std_normalization=True,  # divide inputs by std of the dataset
        
)


train_datagen.fit(train_features)

val_datagen.fit(test_features)

training_generator=train_datagen.flow(train_features,train_labels, batch_size=batch_size,shuffle=True,seed=42)

validation_generator=val_datagen.flow(test_features,test_labels, batch_size=batch_size,shuffle=True,seed=42)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(training_generator, epochs=100, 
                        steps_per_epoch=np.ceil(train_features.shape[0]/batch_size), 
                    validation_steps=np.ceil(test_features.shape[0]/batch_size), 
                    validation_data=validation_generator,
                                 shuffle=True,
                                 callbacks=[chkpoint_model],
                                 verbose=1)
# Out:
# W0717 04:03:47.176633 139781615036288 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 391/391 [==============================] - 58s 149ms/step - loss: 2.2644 - acc: 0.3275 - val_loss: 2.1385 - val_acc: 0.3838
#
# Epoch 00001: val_acc improved from -inf to 0.38380, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 2/100
# 391/391 [==============================] - 51s 130ms/step - loss: 2.0119 - acc: 0.4247 - val_loss: 1.9260 - val_acc: 0.4546
#
# Epoch 00002: val_acc improved from 0.38380 to 0.45460, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 3/100
# 391/391 [==============================] - 51s 130ms/step - loss: 1.8726 - acc: 0.4767 - val_loss: 1.8447 - val_acc: 0.4826
#
# Epoch 00003: val_acc improved from 0.45460 to 0.48260, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 4/100
# 391/391 [==============================] - 51s 130ms/step - loss: 1.7642 - acc: 0.5132 - val_loss: 1.7010 - val_acc: 0.5311
#
# Epoch 00004: val_acc improved from 0.48260 to 0.53110, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 5/100
# 391/391 [==============================] - 51s 129ms/step - loss: 1.6785 - acc: 0.5449 - val_loss: 1.6169 - val_acc: 0.5575
#
# Epoch 00005: val_acc improved from 0.53110 to 0.55750, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 6/100
# 391/391 [==============================] - 50s 129ms/step - loss: 1.6066 - acc: 0.5677 - val_loss: 1.6405 - val_acc: 0.5561
#
# Epoch 00006: val_acc did not improve from 0.55750
# Epoch 7/100
# 391/391 [==============================] - 51s 129ms/step - loss: 1.5397 - acc: 0.5899 - val_loss: 2.1627 - val_acc: 0.4766
#
# Epoch 00007: val_acc did not improve from 0.55750
# Epoch 8/100
# 391/391 [==============================] - 50s 129ms/step - loss: 1.4850 - acc: 0.6075 - val_loss: 1.9761 - val_acc: 0.5138
#
# Epoch 00008: val_acc did not improve from 0.55750
# Epoch 9/100
# 391/391 [==============================] - 50s 129ms/step - loss: 1.4321 - acc: 0.6250 - val_loss: 1.6149 - val_acc: 0.5806
#
# Epoch 00009: val_acc improved from 0.55750 to 0.58060, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 10/100
# 391/391 [==============================] - 50s 129ms/step - loss: 1.3823 - acc: 0.6436 - val_loss: 1.4414 - val_acc: 0.6228
#
# Epoch 00010: val_acc improved from 0.58060 to 0.62280, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 11/100
# 391/391 [==============================] - 51s 129ms/step - loss: 1.3463 - acc: 0.6570 - val_loss: 1.4137 - val_acc: 0.6308
#
# Epoch 00011: val_acc improved from 0.62280 to 0.63080, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 12/100
# 391/391 [==============================] - 50s 129ms/step - loss: 1.2982 - acc: 0.6703 - val_loss: 1.5946 - val_acc: 0.6021
#
# Epoch 00012: val_acc did not improve from 0.63080
# Epoch 13/100
# 391/391 [==============================] - 50s 129ms/step - loss: 1.2685 - acc: 0.6805 - val_loss: 1.3141 - val_acc: 0.6718
#
# Epoch 00013: val_acc improved from 0.63080 to 0.67180, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 14/100
# 391/391 [==============================] - 50s 129ms/step - loss: 1.2319 - acc: 0.6940 - val_loss: 1.2589 - val_acc: 0.6838
#
# Epoch 00014: val_acc improved from 0.67180 to 0.68380, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 15/100
# 391/391 [==============================] - 50s 129ms/step - loss: 1.1951 - acc: 0.7031 - val_loss: 1.5879 - val_acc: 0.6119
#
# Epoch 00015: val_acc did not improve from 0.68380
# Epoch 16/100
# 391/391 [==============================] - 50s 129ms/step - loss: 1.1695 - acc: 0.7115 - val_loss: 1.2652 - val_acc: 0.6808
#
# Epoch 00016: val_acc did not improve from 0.68380
# Epoch 17/100
# 391/391 [==============================] - 51s 130ms/step - loss: 1.1386 - acc: 0.7210 - val_loss: 1.3909 - val_acc: 0.6530
#
# Epoch 00017: val_acc did not improve from 0.68380
# Epoch 18/100
# 391/391 [==============================] - 51s 129ms/step - loss: 1.1065 - acc: 0.7330 - val_loss: 1.1639 - val_acc: 0.7209
#
# Epoch 00018: val_acc improved from 0.68380 to 0.72090, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 19/100
# 391/391 [==============================] - 51s 130ms/step - loss: 1.0803 - acc: 0.7413 - val_loss: 1.2219 - val_acc: 0.6952
#
# Epoch 00019: val_acc did not improve from 0.72090
# Epoch 20/100
# 391/391 [==============================] - 51s 130ms/step - loss: 1.0608 - acc: 0.7480 - val_loss: 1.2158 - val_acc: 0.7069
#
# Epoch 00020: val_acc did not improve from 0.72090
# Epoch 21/100
# 391/391 [==============================] - 51s 130ms/step - loss: 1.0357 - acc: 0.7537 - val_loss: 1.5279 - val_acc: 0.6220
#
# Epoch 00021: val_acc did not improve from 0.72090
# Epoch 22/100
# 391/391 [==============================] - 51s 130ms/step - loss: 1.0176 - acc: 0.7579 - val_loss: 1.1156 - val_acc: 0.7371
#
# Epoch 00022: val_acc improved from 0.72090 to 0.73710, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 23/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.9927 - acc: 0.7647 - val_loss: 1.3883 - val_acc: 0.6781
#
# Epoch 00023: val_acc did not improve from 0.73710
# Epoch 24/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.9780 - acc: 0.7681 - val_loss: 1.2511 - val_acc: 0.7025
#
# Epoch 00024: val_acc did not improve from 0.73710
# Epoch 25/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.9610 - acc: 0.7727 - val_loss: 1.1476 - val_acc: 0.7329
#
# Epoch 00025: val_acc did not improve from 0.73710
# Epoch 26/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.9478 - acc: 0.7768 - val_loss: 1.1401 - val_acc: 0.7280
#
# Epoch 00026: val_acc did not improve from 0.73710
# Epoch 27/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.9222 - acc: 0.7843 - val_loss: 0.9527 - val_acc: 0.7801
#
# Epoch 00027: val_acc improved from 0.73710 to 0.78010, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 28/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.9141 - acc: 0.7873 - val_loss: 0.9533 - val_acc: 0.7822
#
# Epoch 00028: val_acc improved from 0.78010 to 0.78220, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 29/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.8976 - acc: 0.7928 - val_loss: 0.9268 - val_acc: 0.7866
#
# Epoch 00029: val_acc improved from 0.78220 to 0.78660, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 30/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.8790 - acc: 0.7970 - val_loss: 1.2028 - val_acc: 0.7100
#
# Epoch 00030: val_acc did not improve from 0.78660
# Epoch 31/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.8653 - acc: 0.8003 - val_loss: 1.0419 - val_acc: 0.7630
#
# Epoch 00031: val_acc did not improve from 0.78660
# Epoch 32/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.8605 - acc: 0.8001 - val_loss: 0.8764 - val_acc: 0.8050
#
# Epoch 00032: val_acc improved from 0.78660 to 0.80500, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 33/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.8369 - acc: 0.8101 - val_loss: 0.9507 - val_acc: 0.7776
#
# Epoch 00033: val_acc did not improve from 0.80500
# Epoch 34/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.8298 - acc: 0.8091 - val_loss: 0.8880 - val_acc: 0.8016
#
# Epoch 00034: val_acc did not improve from 0.80500
# Epoch 35/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.8142 - acc: 0.8148 - val_loss: 1.0028 - val_acc: 0.7625
#
# Epoch 00035: val_acc did not improve from 0.80500
# Epoch 36/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.8047 - acc: 0.8169 - val_loss: 0.8356 - val_acc: 0.8136
#
# Epoch 00036: val_acc improved from 0.80500 to 0.81360, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 37/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.7992 - acc: 0.8189 - val_loss: 0.8417 - val_acc: 0.8138
#
# Epoch 00037: val_acc improved from 0.81360 to 0.81380, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 38/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.7883 - acc: 0.8203 - val_loss: 0.8853 - val_acc: 0.7899
#
# Epoch 00038: val_acc did not improve from 0.81380
# Epoch 39/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.7731 - acc: 0.8257 - val_loss: 0.9198 - val_acc: 0.7904
#
# Epoch 00039: val_acc did not improve from 0.81380
# Epoch 40/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.7613 - acc: 0.8286 - val_loss: 1.0011 - val_acc: 0.7677
#
# Epoch 00040: val_acc did not improve from 0.81380
# Epoch 41/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.7529 - acc: 0.8296 - val_loss: 0.8547 - val_acc: 0.8035
#
# Epoch 00041: val_acc did not improve from 0.81380
# Epoch 42/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.7422 - acc: 0.8336 - val_loss: 0.8662 - val_acc: 0.7942
#
# Epoch 00042: val_acc did not improve from 0.81380
# Epoch 43/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.7353 - acc: 0.8336 - val_loss: 0.8278 - val_acc: 0.8126
#
# Epoch 00043: val_acc did not improve from 0.81380
# Epoch 44/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.7289 - acc: 0.8356 - val_loss: 0.9727 - val_acc: 0.7703
#
# Epoch 00044: val_acc did not improve from 0.81380
# Epoch 45/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.7161 - acc: 0.8394 - val_loss: 0.8505 - val_acc: 0.8021
#
# Epoch 00045: val_acc did not improve from 0.81380
# Epoch 46/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.7088 - acc: 0.8399 - val_loss: 0.8622 - val_acc: 0.8000
#
# Epoch 00046: val_acc did not improve from 0.81380
# Epoch 47/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.6985 - acc: 0.8448 - val_loss: 0.8571 - val_acc: 0.8061
#
# Epoch 00047: val_acc did not improve from 0.81380
# Epoch 48/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.6899 - acc: 0.8458 - val_loss: 0.8963 - val_acc: 0.7980
#
# Epoch 00048: val_acc did not improve from 0.81380
# Epoch 49/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.6828 - acc: 0.8497 - val_loss: 0.7769 - val_acc: 0.8278
#
# Epoch 00049: val_acc improved from 0.81380 to 0.82780, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 50/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.6729 - acc: 0.8505 - val_loss: 1.0907 - val_acc: 0.7502
#
# Epoch 00050: val_acc did not improve from 0.82780
# Epoch 51/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.6643 - acc: 0.8528 - val_loss: 0.8772 - val_acc: 0.7952
#
# Epoch 00051: val_acc did not improve from 0.82780
# Epoch 52/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.6601 - acc: 0.8534 - val_loss: 0.8808 - val_acc: 0.8090
#
# Epoch 00052: val_acc did not improve from 0.82780
# Epoch 53/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.6525 - acc: 0.8551 - val_loss: 0.8670 - val_acc: 0.8025
#
# Epoch 00053: val_acc did not improve from 0.82780
# Epoch 54/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.6470 - acc: 0.8587 - val_loss: 0.8297 - val_acc: 0.8070
#
# Epoch 00054: val_acc did not improve from 0.82780
# Epoch 55/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.6447 - acc: 0.8575 - val_loss: 0.8150 - val_acc: 0.8169
#
# Epoch 00055: val_acc did not improve from 0.82780
# Epoch 56/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.6364 - acc: 0.8587 - val_loss: 0.7646 - val_acc: 0.8285
#
# Epoch 00056: val_acc improved from 0.82780 to 0.82850, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 57/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.6265 - acc: 0.8614 - val_loss: 1.2466 - val_acc: 0.7295
#
# Epoch 00057: val_acc did not improve from 0.82850
# Epoch 58/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.6194 - acc: 0.8631 - val_loss: 0.9159 - val_acc: 0.8052
#
# Epoch 00058: val_acc did not improve from 0.82850
# Epoch 59/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.6140 - acc: 0.8681 - val_loss: 0.7734 - val_acc: 0.8280
#
# Epoch 00059: val_acc did not improve from 0.82850
# Epoch 60/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.6075 - acc: 0.8650 - val_loss: 0.7753 - val_acc: 0.8234
#
# Epoch 00060: val_acc did not improve from 0.82850
# Epoch 61/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.6053 - acc: 0.8654 - val_loss: 0.6962 - val_acc: 0.8483
#
# Epoch 00061: val_acc improved from 0.82850 to 0.84830, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 62/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.5945 - acc: 0.8707 - val_loss: 0.7763 - val_acc: 0.8297
#
# Epoch 00062: val_acc did not improve from 0.84830
# Epoch 63/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.5886 - acc: 0.8697 - val_loss: 0.8285 - val_acc: 0.8115
#
# Epoch 00063: val_acc did not improve from 0.84830
# Epoch 64/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.5852 - acc: 0.8711 - val_loss: 0.8013 - val_acc: 0.8262
#
# Epoch 00064: val_acc did not improve from 0.84830
# Epoch 65/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.5756 - acc: 0.8745 - val_loss: 0.7997 - val_acc: 0.8210
#
# Epoch 00065: val_acc did not improve from 0.84830
# Epoch 66/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.5709 - acc: 0.8735 - val_loss: 0.7093 - val_acc: 0.8422
#
# Epoch 00066: val_acc did not improve from 0.84830
# Epoch 67/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.5714 - acc: 0.8745 - val_loss: 0.8454 - val_acc: 0.8124
#
# Epoch 00067: val_acc did not improve from 0.84830
# Epoch 68/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.5648 - acc: 0.8759 - val_loss: 0.7647 - val_acc: 0.8322
#
# Epoch 00068: val_acc did not improve from 0.84830
# Epoch 69/100
# 391/391 [==============================] - 51s 131ms/step - loss: 0.5610 - acc: 0.8760 - val_loss: 1.0132 - val_acc: 0.7764
#
# Epoch 00069: val_acc did not improve from 0.84830
# Epoch 70/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5541 - acc: 0.8795 - val_loss: 0.7635 - val_acc: 0.8230
#
# Epoch 00070: val_acc did not improve from 0.84830
# Epoch 71/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5535 - acc: 0.8781 - val_loss: 0.7955 - val_acc: 0.8176
#
# Epoch 00071: val_acc did not improve from 0.84830
# Epoch 72/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5489 - acc: 0.8802 - val_loss: 0.8422 - val_acc: 0.8124
#
# Epoch 00072: val_acc did not improve from 0.84830
# Epoch 73/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5403 - acc: 0.8807 - val_loss: 0.7298 - val_acc: 0.8349
#
# Epoch 00073: val_acc did not improve from 0.84830
# Epoch 74/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5342 - acc: 0.8833 - val_loss: 0.9534 - val_acc: 0.7973
#
# Epoch 00074: val_acc did not improve from 0.84830
# Epoch 75/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5283 - acc: 0.8872 - val_loss: 0.9282 - val_acc: 0.7994
#
# Epoch 00075: val_acc did not improve from 0.84830
# Epoch 76/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5270 - acc: 0.8864 - val_loss: 0.7732 - val_acc: 0.8329
#
# Epoch 00076: val_acc did not improve from 0.84830
# Epoch 77/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5211 - acc: 0.8874 - val_loss: 0.8450 - val_acc: 0.8188
#
# Epoch 00077: val_acc did not improve from 0.84830
# Epoch 78/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5214 - acc: 0.8858 - val_loss: 0.8457 - val_acc: 0.8197
#
# Epoch 00078: val_acc did not improve from 0.84830
# Epoch 79/100
# 391/391 [==============================] - 58s 149ms/step - loss: 0.5179 - acc: 0.8865 - val_loss: 0.7791 - val_acc: 0.8285
#
# Epoch 00079: val_acc did not improve from 0.84830
# Epoch 80/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5141 - acc: 0.8882 - val_loss: 0.6423 - val_acc: 0.8599
#
# Epoch 00080: val_acc improved from 0.84830 to 0.85990, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 81/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5109 - acc: 0.8886 - val_loss: 0.7470 - val_acc: 0.8352
#
# Epoch 00081: val_acc did not improve from 0.85990
# Epoch 82/100
# 391/391 [==============================] - 51s 129ms/step - loss: 0.5029 - acc: 0.8914 - val_loss: 0.6430 - val_acc: 0.8573
#
# Epoch 00082: val_acc did not improve from 0.85990
# Epoch 83/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5074 - acc: 0.8882 - val_loss: 0.7750 - val_acc: 0.8254
#
# Epoch 00083: val_acc did not improve from 0.85990
# Epoch 84/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.5004 - acc: 0.8927 - val_loss: 0.8450 - val_acc: 0.8072
#
# Epoch 00084: val_acc did not improve from 0.85990
# Epoch 85/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.4972 - acc: 0.8920 - val_loss: 0.7962 - val_acc: 0.8175
#
# Epoch 00085: val_acc did not improve from 0.85990
# Epoch 86/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.4956 - acc: 0.8932 - val_loss: 0.8364 - val_acc: 0.8191
#
# Epoch 00086: val_acc did not improve from 0.85990
# Epoch 87/100
# 391/391 [==============================] - 51s 130ms/step - loss: 0.4842 - acc: 0.8954 - val_loss: 0.6791 - val_acc: 0.8538
#
# Epoch 00087: val_acc did not improve from 0.85990
# Epoch 88/100
# 391/391 [==============================] - 56s 144ms/step - loss: 0.4924 - acc: 0.8915 - val_loss: 0.7896 - val_acc: 0.8317
#
# Epoch 00088: val_acc did not improve from 0.85990
# Epoch 89/100
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4841 - acc: 0.8961 - val_loss: 0.7007 - val_acc: 0.8461
#
# Epoch 00089: val_acc did not improve from 0.85990
# Epoch 90/100
# 391/391 [==============================] - 52s 133ms/step - loss: 0.4787 - acc: 0.8971 - val_loss: 0.8536 - val_acc: 0.8014
#
# Epoch 00090: val_acc did not improve from 0.85990
# Epoch 91/100
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4787 - acc: 0.8970 - val_loss: 0.6657 - val_acc: 0.8514
#
# Epoch 00091: val_acc did not improve from 0.85990
# Epoch 92/100
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4752 - acc: 0.8972 - val_loss: 0.6586 - val_acc: 0.8530
#
# Epoch 00092: val_acc did not improve from 0.85990
# Epoch 93/100
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4675 - acc: 0.9000 - val_loss: 0.8138 - val_acc: 0.8285
#
# Epoch 00093: val_acc did not improve from 0.85990
# Epoch 94/100
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4683 - acc: 0.9001 - val_loss: 0.6680 - val_acc: 0.8614
#
# Epoch 00094: val_acc improved from 0.85990 to 0.86140, saving model to /gdrive/My Drive/EIP3/session5/best_model3.h5
# Epoch 95/100
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4601 - acc: 0.9015 - val_loss: 0.8926 - val_acc: 0.8040
#
# Epoch 00095: val_acc did not improve from 0.86140
# Epoch 96/100
# 391/391 [==============================] - 51s 132ms/step - loss: 0.4573 - acc: 0.9024 - val_loss: 0.6574 - val_acc: 0.8580
#
# Epoch 00096: val_acc did not improve from 0.86140
# Epoch 97/100
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4638 - acc: 0.8987 - val_loss: 0.8207 - val_acc: 0.8193
#
# Epoch 00097: val_acc did not improve from 0.86140
# Epoch 98/100
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4523 - acc: 0.9043 - val_loss: 0.6920 - val_acc: 0.8525
#
# Epoch 00098: val_acc did not improve from 0.86140
# Epoch 99/100
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4543 - acc: 0.9028 - val_loss: 0.6915 - val_acc: 0.8456
#
# Epoch 00099: val_acc did not improve from 0.86140
# Epoch 100/100
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4463 - acc: 0.9048 - val_loss: 0.7232 - val_acc: 0.8399
#
# Epoch 00100: val_acc did not improve from 0.86140

# %% [markdown]
# ### The network was trained for 100 epochs and reached a max validation accuracy of 86.14 .
# ### There is still scope for this model to learn if trained for more epochs as the training accuracy is only at 90.5 but we will stop here and focus on GradCAM visualization .
# ### We have saved the model with best validation accuracy in google drive so that we can load and use it for prediction and Grad-CAM visualization
#
# #GRAD-CAM
#
# ### Now let us define the function for Grad-CAM visualization .
# ### This function named gradcam takes as input the model , the set of images , the labels for each image and the layer to be used for calculating gradients .
# ### It returns a list of dictionaries containing original image , the heatmap, the titles to display during visualization

# %%
import cv2
from mpl_toolkits.axes_grid1 import ImageGrid
from google.colab.patches import cv2_imshow
from IPython.core.display import display, HTML


#select test images and corresponding labels to print heatmap 
#x=np.array([test_features[41],test_features[410],test_features[222],test_features[950]])
#y=[test_labels[41],test_labels[410],test_labels[222],test_labels[950]]


def gradcam(model1,x,y,which_layer):
  #
  results=[]
  #make prediction for these 4 images 
  preds = model1.predict(x)
  for j in range(x.shape[0]):
    #get class id from the prediction values 
    class_idx = np.argmax(preds[j])

    class_output = model1.output[:, class_idx]
  
    ## choose the layer nearest to prediction that has a size of about 7x7 or 8x8 
    #in this case it is the layer being sent to the gradcam function 
    last_conv_layer = model1.get_layer(which_layer)
  
    # compute gradients and from heatmap 
    grads = K.gradients(class_output, last_conv_layer.output)[0]
    pooled_grads = K.mean(grads, axis=(0, 1, 2))
    iterate = K.function([model1.input], [pooled_grads, last_conv_layer.output[0]])
    pooled_grads_value, conv_layer_output_value = iterate([x])
    
    #apply the pooled grad value to the conv layer channels 
    for i in range(10):
      
      conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
      
    #get the mean of the weighted values and assign to heatmap   
    heatmap = np.mean(conv_layer_output_value, axis=-1)
    #retain only positive values (or 0) in heatmap 
    heatmap = np.maximum(heatmap, 0)
    #convert values between 0 and 1 using divide by max value 
    heatmap /= np.max(heatmap) 
    #we now have a heatmap with size equal to the output size of the layer we chose 
    
    #img is the image we are running gradcam on 
    img = x[j]
    
    #resize heatmap 8x8 to image size of 32x32 
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    #convert pixel values to be between 0 and 255 
    heatmap = np.uint8(255 * heatmap)
    #apply suitable cv2 colormap . In this case colormap_JET 
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  
    # convert from BGR to RGB if we want to display using matplotlib 
    heatmap1 = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)
    
    # create superimposed image if we want to print using cv2 (cv2_imshow supported in colab)
    superimposed_img = cv2.addWeighted(img, 0.5, heatmap1, 0.5, 0,dtype=5)
    
    #create a dictionary object with details of image, heatmap, its title 
    title1=str(j+1)+": "+ class_names[np.argmax(y[j])]+"\npredicted as\n"+str(class_names[class_idx])
    title2='superimposed\nheatmap'
    image1=img
    image2=heatmap1
    image3=superimposed_img
    imageObj={'image1':image1,'image2':image2,'image3':image3,'title1':title1,'title2':title2}
    
    #append the image dict object to results list 
    results.append(imageObj)
    #print(j)
  #return grad-cam results as a list of dictionary objects , each containing an image and its heatmap  
  return results

# %% [markdown]
# ### Define the function to display the Grad-CAM visualizations .
# ### This function displays a set of two images with heatmap visuals per row

# %%
def displayRow(images):
  # we will plot 2 images in a row 
  # cv.imshow does not work in jupyter notebooks and colab 
  # cv2_imshow patch works on colab but matplotlib gives us a little more flexibility in formatting the display
  # we will use matplotlib to print the image and its heatmap 
  fig = plt.figure(1, (13,13))

  grid = ImageGrid(fig, 111,  
                 nrows_ncols=(1,5),  
                 axes_pad=1,label_mode="1"  
                 )
  
  #horizontal spacer
  
    
  #grid[0].imshow(np.ones((32, 10)),alpha=0)
  #grid[0].axis('off')
  
  
  
  #first image
  #print(" original class is :"+class_names[np.argmax(y[j])]+" and predicted class is :"+str(class_names[class_idx]))
  grid[0].imshow(images[0]['image1'])
  grid[0].set_title(images[0]['title1'])
  grid[0].axis('off')
  
  #print the original image and on top of it place the heat map at 60% transparency 
  grid[1].imshow(images[0]['image1'],alpha=0.9)
  grid[1].imshow(images[0]['image2'],alpha=0.6)
  grid[1].set_title(images[0]['title2'])
  grid[1].axis('off')
  
  #vertical separator 
    
  grid[2].imshow(np.ones((32, 1)))
  grid[2].axis('off')
  
  #second image 
    
  #print(" original class is :"+class_names[np.argmax(y[j])]+" and predicted class is :"+str(class_names[class_idx]))
  grid[3].imshow(images[1]['image1'])
  grid[3].set_title(images[1]['title1'])
  grid[3].axis('off')
  
  #print the original image and on top of it place the heat map at 60% transparency 
  grid[4].imshow(images[1]['image1'],alpha=0.9)
  grid[4].imshow(images[1]['image2'],alpha=0.6)
  grid[4].set_title(images[1]['title2'])
  grid[4].axis('off')
  
  
  
  plt.show()
  display(HTML("<hr size='5' color='black' width='100%' align='center' />"))

# %% [markdown]
# ### Now that we have done the preparatory work for the visualization , let us load the model with best validation accuracy from earlier training

# %%
from keras.models import load_model
model=load_model(model_save_path)

# %% [markdown]
# ### Make predictions using the model and collect all the images that were classified wrongly

# %%
pred=model.predict(test_features)
pred2=np.argmax(pred,axis=1)
wrong_set=[]
correct_set=[]
wrong_labels=[]
true_labels=[]
wrong_indices=[]
for i in range(test_features.shape[0]):
  
  if (pred2[i]==np.argmax(test_labels[i])):
    
    correct_set.append(test_features[i])
  else:
    wrong_indices.append(i)
    wrong_labels.append(class_names[pred2[i]])
    true_labels.append(class_names[np.argmax(test_labels[i])])
    wrong_set.append(test_features[i])

# %% [markdown]
# ### Now take the first 50 images and the corresponding labels to create the data for Grad-CAM visualization

# %%
#take the first 50 images and labels from misclassified set 
w_list=wrong_indices[:50]
x=[]
y=[]
for i in range(len(w_list)):
  x.append(test_features[w_list[i]])
  y.append(test_labels[w_list[i]])
  
#convert the image list to numpy array   
x=np.array(x)

# %% [markdown]
# ### Obtain results from the gradcam function

# %%
results=gradcam(model,x,y,'reducer1') # we choose this layer as the layer nearest to prediction and having a size of 8x8

# %% [markdown]
# ### display the results from gradcam function with images and corresponding heatmap visuals

# %%
display(HTML("<h2 align='center'>First 50 misclassified images with Grad-CAM heatmap </h2><hr size='5' color='black' width='100%' align='center' />"))
for i in range(0,len(results),2):
  images=[]
  images.append(results[i])
  images.append(results[i+1])
  displayRow(images)
# Out:
# <h2 align='center'>First 50 misclassified images with Grad-CAM heatmap </h2><hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />
# <hr size='5' color='black' width='100%' align='center' />

# %% [markdown]
# ### We used a ResNet20 model as per the experiments done by the original authors of ResNet for CIFAR10 dataset . We made predictions on the dataset and collected 50 misclassified images. We then used Grad-CAM to visualize the heatmap for each of these 50 images and displayed the images together with the heatmaps for a better undertsanding of where the model is looking at or which pixels in a chosen layer are most actively contributing when making predictions for a certain class
